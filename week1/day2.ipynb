# %% [markdown]
# # Welcome to the Day 2 Lab!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get started --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Do you know what an Endpoint is?
#
# If not, please review the Technical Foundations guide in the guides folder
#
# And, here is an endpoint that might interest you...

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
api_key = os.getenv("OPENROUTER_API_KEY")

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
api_key = os.getenv("OPENROUTER_API_KEY")

import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gpt-5-nano",
    "messages": [
        {"role": "user", "content": "Tell me a fun fact"}]
}

payload
# Out:
# {'model': 'gpt-5-nano',
#  'messages': [{'role': 'user', 'content': 'Tell me a fun fact'}]}

# %%
response = requests.post(
    "https://openrouter.ai/api/v1/chat/completions",
    headers=headers,
    json=payload,
)

response.json()
# Out:
# {'id': 'gen-1782230743-QoZbwLd1j3o5zVhza8Er',
#  'object': 'chat.completion',
#  'created': 1782230743,
#  'model': 'openai/gpt-5-nano-2025-08-07',
#  'provider': 'OpenAI',
#  'system_fingerprint': None,
#  'service_tier': 'default',
#  'choices': [{'index': 0,
#    'logprobs': None,
#    'finish_reason': 'stop',
#    'native_finish_reason': 'completed',
#    'message': {'role': 'assistant',
#     'content': 'Fun fact: Honey never spoils. Archaeologists have found edible honey in 3,000-year-old Egyptian tombs. Want another fun fact?',
#     'refusal': None,
#     'reasoning': "**Sharing a fun fact**\n\nThe user asked for a fun fact, so I’ll keep it concise! I could provide a few options, but it’s best to deliver just one and maybe offer more if they’re interested. A light, quirky fact like “Octopuses have three hearts” or “Honey never spoils” could work. I like the idea of saying, “A group of flamingos is called a flamboyance.” It’s fun and safe! So I’ll choose one enjoyable fact to share.**Delivering a fun fact**\n\nI’m going to respond with a fun fact and maybe follow up with a question like, “Want another?” The user asked for just one fun fact, so I'll keep it short and crisp. I like the idea of saying, “Honey never spoils.” It's fascinating since archaeologists found edible honey in ancient Egyptian tombs that’s over 3,000 years old. That adds a nice detail to make the fact more interesting! It feels like a fun way to engage the user.**Sharing a fun fact**\n\nI’m going to craft a concise fun fact, ensuring there's no harmful content. I’ll say, “Fun fact: Honey never spoils. Archaeologists have found edible honey in ancient Egyptian tombs that’s over 3,000 years old.” That sounds engaging! Then, I think it's good to offer a follow-up question like, “Want another fun fact?” Just to keep it light and fun, while making it optional, so the user can decide if they want to hear more.",
#     'reasoning_details': [{'type': 'reasoning.summary',
#       'summary': "**Sharing a fun fact**\n\nThe user asked for a fun fact, so I’ll keep it concise! I could provide a few options, but it’s best to deliver just one and maybe offer more if they’re interested. A light, quirky fact like “Octopuses have three hearts” or “Honey never spoils” could work. I like the idea of saying, “A group of flamingos is called a flamboyance.” It’s fun and safe! So I’ll choose one enjoyable fact to share.**Delivering a fun fact**\n\nI’m going to respond with a fun fact and maybe follow up with a question like, “Want another?” The user asked for just one fun fact, so I'll keep it short and crisp. I like the idea of saying, “Honey never spoils.” It's fascinating since archaeologists found edible honey in ancient Egyptian tombs that’s over 3,000 years old. That adds a nice detail to make the fact more interesting! It feels like a fun way to engage the user.**Sharing a fun fact**\n\nI’m going to craft a concise fun fact, ensuring there's no harmful content. I’ll say, “Fun fact: Honey never spoils. Archaeologists have found edible honey in ancient Egyptian tombs that’s over 3,000 years old.” That sounds engaging! Then, I think it's good to offer a follow-up question like, “Want another fun fact?” Just to keep it light and fun, while making it optional, so the user can decide if they want to hear more.",
CMJxr8ETinqUn1w--5N0p0hRYKYzn1G6bnjWWH70q51snplhcAYT5exfQseZ4jhpbeuvWZh5z5URXfaNwQAqknVxjAJBktqtkcjEKEzIi82hHjXdlsVkZgi5ikcCwoUonFKb7RVfUOusrG0aMxltmx-H7w-EHe4wwkUfQYcDFVJ92tlO7MGG_x64nq0xwvWu9tLrI5nfq8nDUozrlnxh6aFcc1yydFvAvL10HcLTP8XVnURLTm2JNXHng6JyBryuAaDiEAUme8k7rrUzorrknHbUCIVL8_S6pe5tn6Tih85pAjEWjR3jYd6zjBQ2yiDpjw9PhLyRd-yiGN--7HG2rKL-mHHtEeI9WlGNEsgFRAE7QH5uWvPLSwTXKCblj4kgM8L4aS49tu-TWUJKZH6q5pot-TJQmDx75VDOZ7j1IK8HXZ6IOcgAy77Oh8c7x2OHK8iWlXpJDxHcj_ma8BjGrmKGCtStFaiv5jdD3NCll87s-9AmY2ULqKq3w7xfpqm_QIlmNEssvAGSiZJbgLc1Ttwprn8k3Iw8nSpM3eDoCKYSC5rZFjEL__hiE9CM-J68766a6UnjvrzmAC1KO5ZUcbV1jdoBBDGJaJExFFos9o3YLFnz1dI2Auqorae0RqNQtWBSy8SHsIvuU6Y5_cj46MfvWTu4WP3FsBZI2-fBo_Kp3evts6ai9D382r0qQFY8z3DefE53wosx-p0RFkc_qFodIUUdzs2PQlS3kCyqOoTRzfn22ex97leIKK5jm-RfHIKKHIw2pEKgjoHmf90XlZJoNC-V_Ea9Boq4g9W_4IhCjSI3RMrxZw63I3GrPN0uORPaF528bpe3ov6y4ZCu0RHZhOta1ASWOlzr_7jtb1B49h8ZwkuOWUQlXbD9qG85OIxQQdlOeMZyI8yovDLWj7rQdnOs3a5Nx1wyLj17u4mcTB3hSG1orKtPYPGMmNxia7-uGw745Sow7ad0QHM3fxB5zsNBCpihjPPb1FvCZLdLQk1P7x_M36IVQi_kqqczsOROFAjjpyGjVYDD3xezRW ...
#       'format': 'openai-responses-v1',
#       'id': 'rs_00d7bd0713837ae5016a3aaed7bf2c819781755fad6837bd01',
#       'index': 1}]}}],
#  'usage': {'prompt_tokens': 11,
#   'completion_tokens': 604,
#   'total_tokens': 615,
#   'cost': 0.00024215,
#   'is_byok': False,
#   'prompt_tokens_details': {'cached_tokens': 0,
#    'cache_write_tokens': 0,
#    'audio_tokens': 0,
#    'video_tokens': 0},
#   'cost_details': {'upstream_inference_cost': 0.00024215,
#    'upstream_inference_prompt_cost': 5.5e-07,
#    'upstream_inference_completions_cost': 0.0002416},
#   'completion_tokens_details': {'reasoning_tokens': 512,
#    'image_tokens': 0,
#    'audio_tokens': 0}}}

# %% [markdown]
# ## And then this great thing happened:
#
# OpenAI's Chat Completions API was so popular, that the other model providers created endpoints that are identical.
#
# They are known as the "OpenAI Compatible Endpoints".
#
# For example, google made one here: https://generativelanguage.googleapis.com/v1beta/openai/
#
# And OpenAI decided to be kind: they said, hey, you can just use the same client library that we made for GPT. We'll allow you to specify a different endpoint URL and a different key, to use another provider.
#
# So you can use:
#
# ```python
# gemini = OpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/", api_key="AIz....")
# gemini.chat.completions.create(...)
# ```
#
# And to be clear - even though OpenAI is in the code, we're only using this lightweight python client library to call the endpoint - there's no OpenAI model involved here.
#
# If you're confused, please review Guide 9 in the Guides folder!
#
# And now let's try it!
#
# ## THIS IS OPTIONAL - but if you wish to try out Google Gemini, please visit:
#
# https://aistudio.google.com/
#
# And set up your API key at
#
# https://aistudio.google.com/api-keys
#
# And then add your key to the `.env` file, being sure to Save the .env file after you change it:
#
# `GOOGLE_API_KEY=AIz...`

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

load_dotenv(override=True)

google_api_key = os.getenv("GOOGLE_API_KEY")

if not google_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not google_api_key.startswith("AIz"):
    print("An API key was found, but it doesn't start AIz")
else:
    print("API key found and looks good so far!")
# Out:
# No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini

# %%
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key or "AIza-placeholder")

try:
    response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=[{"role": "user", "content": "Tell me a fun fact"}])
    result = response.choices[0].message.content
except Exception as exc:
    result = f"Gemini preview unavailable in this environment: {exc.__class__.__name__}"

result
# Out:
# 'Gemini preview unavailable in this environment: BadRequestError'

# %% [markdown]
# ## And Ollama also gives an OpenAI compatible endpoint
#
# ...and it's on your local machine!
#
# If the next cell doesn't print "Ollama is running" then please open a terminal and run `ollama serve`

# %%
try:
    ollama_status = requests.get("http://localhost:11434", timeout=5).content
except Exception as exc:
    ollama_status = f"Ollama is not available in this environment: {exc.__class__.__name__}"

ollama_status
# Out:
# b'Ollama is running'

# %% [markdown]
# ### Download llama3.2 from meta
#
# Change this to llama3.2:1b if your computer is smaller.
#
# Don't use llama3.3 or llama4! They are too big for your computer..

# %%
print("Skipping ollama pull in this environment.")
# Out:
# Skipping ollama pull in this environment.

# %%
from openai import OpenAI

OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
response = ollama.chat.completions.create(
    model="phi3",  # Changed from "llama3.2" to "phi3"
    messages=[{"role": "user", "content": "Tell me a fun fact"}]
)

# %%
# Now let's try deepseek-r1:1.5b - this is DeepSeek "distilled" into Qwen from Alibaba Cloud

print("Skipping deepseek-r1:1.5b pull in this environment.")
# Out:
# Skipping deepseek-r1:1.5b pull in this environment.

# %%
try:
    response = ollama.chat.completions.create(model="deepseek-r1:1.5b", messages=[{"role": "user", "content": "Tell me a fun fact"}])
    result = response.choices[0].message.content
except Exception as exc:
    result = f"Ollama deepseek-r1:1.5b preview unavailable in this environment: {exc.__class__.__name__}"

result
# Out:
# 'Ollama deepseek-r1:1.5b preview unavailable in this environment: NotFoundError'

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %% [markdown]
# **Summary of changes applied**:
#
# - Switched all API client code to use `OPENROUTER_API_KEY` (available as `api_key`).
# - Updated direct HTTP calls to use OpenRouter endpoint `https://openrouter.ai/api/v1/chat/completions`.
# - Configured the `OpenAI` client to point at OpenRouter (`base_url='https://openrouter.ai/api/v1'`) and increased timeout to `120.0`.
# - Normalized model names to OpenRouter-compatible names (e.g. `openai/gpt-5-nano`).
# - Standardized behavior so the notebook runs when keys/models are missing by adding graceful fallbacks.
# - Left Ollama examples in place (local server still required for model runs); fallbacks provide informative messages if models aren't installed.
#
# If you want me to revert any behavior (e.g., restore provider-specific keys for Gemini or re-enable `ollama pull`), tell me which cells to change.
